# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from utils import *

# %%
run_list = [0, 1, 2, 3, 4]
model_list = ['estimator_A', 'estimator_B', 'linear_regression', 'nn', 'vit']

def get_prediction_path(run, model):
    # run in [0, 1, 2, 3, 4]
    # model in ['estimator_A', 'estimator_B', 'linear_regression', 'nn']
    return f"./predictions/{run}_{model}.npy"

def get_train_test_indice_path(run):
    return f"./dataset/train_test_split_set_{run}.npy"

# %%
# load train and test data
# load raw data
col_list = ['model', 'run', 'ion_accuracy', 'ion_sensitivity', 'ion_specificity', 'precursor_accuracy', 'precursor_sensitivity', 'precursor_specificity', 'col_accuracy', 'col_sensitivity', 'col_specificity', 'ion_l1', 'ion_mse', 'ion_cosine', 'precursor_l1', 'precursor_mse', 'precursor_cosine', 'col_l1', 'col_mse', 'col_cosine']
data = []

# %%
def get_masked_spectral_distance(cosine):
    arccosine = np.arccos(cosine)
    return 1- 2 * arccosine / np.pi

# %%
# run = 0
# model = "nn"
for model in model_list:
# for model in ['vit']:
    for run in run_list:
        print(f"\n{model} - {run}")
        precursor_info_path = './dataset/precursor_info.tsv'
        matrix_path = './dataset/matrix_mz_prob_mean_var.npy'
        output_dir = './evaluation_outputs'
        indices_path = get_train_test_indice_path(run)

        Y_train, Y_test, precursor_train_df, precursor_test_df = load_train_test_prob(precursor_info_path, indices_path, matrix_path, return_X=False)

        predict_path = get_prediction_path(run, model)
        Y_train_pred, Y_test_pred, _, _ = load_train_test_prob(precursor_info_path, indices_path, predict_path, return_X=False, use_peak_mask=False)
        Y_test_mask = Y_test >= 0
        threshold = 0.001
        Y_test_pred[Y_test_pred < threshold] = 0
        Y_test[Y_test < threshold] = 0
        Y_test_pred_binary = np.where(Y_test_pred > 0, 1, 0)
        Y_test_binary = np.where(Y_test > 0, 1, 0)

        ion_acc_list, ion_sen_list, ion_spec_list, ion_l1_list, ion_mse_list, ion_cosine_list = [], [], [], [], [], []
        precursor_acc_list, precursor_sen_list, precursor_spec_list, precursor_l1_list, precursor_mse_list, precursor_cosine_list = [], [], [], [], [], []
        precursor_sa_list = []

        # 1. look at the TP, FP, TN, FN of if the predictions can show whether their if a fragment is present or not
        # columns: model, run, ion_accuracy, ion_sensitivity, ion_specificity, precursor_accuracy, precursor_sensitivity, precursor_specificity, globel accuracy, globel_sensitivity, globel_specificity, ion_l1, ion_mse, ion_cosine, precursor_l1, precursor_mse, precursor_cosine, globel_l1, globel_mse, globel_cosine
        row = [model, run]

        # frag ion level evaluation
        Y_test_flattened = Y_test[Y_test_mask].flatten()
        Y_test_pred_flattened = Y_test_pred[Y_test_mask].flatten()
        Y_test_flattened_binary = Y_test_binary[Y_test_mask].flatten()
        Y_test_pred_flattened_binary = Y_test_pred_binary[Y_test_mask].flatten()
        accuracy, sensitivity, specificity = get_accuracy_sensitivity_specificity(Y_test_flattened_binary, Y_test_pred_flattened_binary, threshold)
        row += [accuracy, sensitivity, specificity]
        print(f"frag ion level - Accuracy: {accuracy:.5f}, Sensitivity: {sensitivity:.5f}, Specificity: {specificity:.5f}")

        l1 = compute_l1_distance(Y_test_flattened, Y_test_pred_flattened)
        mse = compute_mse(Y_test_flattened, Y_test_pred_flattened)
        cosine = compute_cosine(Y_test_flattened, Y_test_pred_flattened)
        spectral_angle = get_masked_spectral_distance(cosine)
        row += [l1, mse, cosine]
        print(f"frag ion level - L1: {l1:.5f}, MSE: {mse:.5f}, Cosine: {cosine:.5f}, Spectral Angle: {spectral_angle:.5f}") 

        # precursor level evaluation
        num_precursors = precursor_test_df.shape[0]
        averaged_accuracy, averaged_sensitivity, averaged_specificity = 0, 0, 0
        averaged_l1, averaged_mse, averaged_cosine, averaged_spectral_angle = 0, 0, 0, 0
        for i in range(num_precursors):
            Y_test_flattened = Y_test[i][Y_test_mask[i]]
            Y_test_pred_flattened = Y_test_pred[i][Y_test_mask[i]]
            Y_test_flattened_binary = Y_test_binary[i][Y_test_mask[i]]
            Y_test_pred_flattened_binary = Y_test_pred_binary[i][Y_test_mask[i]]
            accuracy, sensitivity, specificity = get_accuracy_sensitivity_specificity(Y_test_flattened_binary, Y_test_pred_flattened_binary, threshold)
            averaged_accuracy += accuracy / num_precursors
            averaged_sensitivity += sensitivity / num_precursors
            averaged_specificity += specificity / num_precursors
            precursor_acc_list.append(accuracy)
            precursor_sen_list.append(sensitivity)
            precursor_spec_list.append(specificity)

            l1 = compute_l1_distance(Y_test_flattened, Y_test_pred_flattened)
            mse = compute_mse(Y_test_flattened, Y_test_pred_flattened)
            cosine = compute_cosine(Y_test_flattened, Y_test_pred_flattened)
            spectral_angle = get_masked_spectral_distance(cosine)
            averaged_l1 += l1 / num_precursors
            averaged_mse += mse / num_precursors
            averaged_cosine += cosine / num_precursors
            averaged_spectral_angle += spectral_angle / num_precursors
            precursor_l1_list.append(l1)
            precursor_mse_list.append(mse)
            precursor_cosine_list.append(cosine)
            precursor_sa_list.append(spectral_angle)
        row += [averaged_accuracy, averaged_sensitivity, averaged_specificity]
        print(f"precursor level - Accuracy: {averaged_accuracy:.5f}, Sensitivity: {averaged_sensitivity:.5f}, Specificity: {averaged_specificity:.5f}")
        row += [averaged_l1, averaged_mse, averaged_cosine]
        print(f"precursor level - L1: {averaged_l1:.5f}, MSE: {averaged_mse:.5f}, Cosine: {averaged_cosine:.5f}, Spectral Angle: {averaged_spectral_angle:.5f}")

        # per considered ion
        num_frag_ions = Y_test.shape[1]
        averaged_accuracy, averaged_sensitivity, averaged_specificity = 0, 0, 0
        averaged_l1, averaged_mse, averaged_cosine = 0, 0, 0
        averaged_spectral_angle = 0        # normalized spectral angle
        for i in range(num_frag_ions):
            y_test_col = Y_test[:, i][Y_test_mask[:, i]]
            y_test_pred_col = Y_test_pred[:, i][Y_test_mask[:, i]]
            y_test_col_binary = Y_test_binary[:, i][Y_test_mask[:, i]]
            y_test_pred_col_binary = Y_test_pred_binary[:, i][Y_test_mask[:, i]]
            accuracy, sensitivity, specificity = get_accuracy_sensitivity_specificity(y_test_col_binary, y_test_pred_col_binary, threshold)
            averaged_accuracy += accuracy / num_frag_ions
            averaged_sensitivity += sensitivity / num_frag_ions
            averaged_specificity += specificity / num_frag_ions
            ion_acc_list.append(accuracy)
            ion_sen_list.append(sensitivity)
            ion_spec_list.append(specificity)

            l1 = compute_l1_distance(y_test_col, y_test_pred_col)
            mse = compute_mse(y_test_col, y_test_pred_col)
            cosine = compute_cosine(y_test_col, y_test_pred_col)
            spectral_angle = get_masked_spectral_distance(cosine)
            averaged_l1 += l1 / num_frag_ions
            averaged_mse += mse / num_frag_ions
            averaged_cosine += cosine / num_frag_ions
            averaged_spectral_angle += spectral_angle / num_frag_ions
            ion_l1_list.append(l1)
            ion_mse_list.append(mse)
            ion_cosine_list.append(cosine)
        row += [averaged_accuracy, averaged_sensitivity, averaged_specificity]
        print(f"averaged over col - Accuracy: {averaged_accuracy:.5f}, Sensitivity: {averaged_sensitivity:.5f}, Specificity: {averaged_specificity:.5f}")
        row += [averaged_l1, averaged_mse, averaged_cosine]
        print(f"averaged over col - L1: {averaged_l1:.5f}, MSE: {averaged_mse:.5f}, Cosine: {averaged_cosine:.5f}, Spectral Angle: {averaged_spectral_angle:.5f}")

        data.append(row)
# Out:
# estimator_A - 0
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.65737, Sensitivity: 1.00000, Specificity: 0.00000
# frag ion level - L1: 0.23976, MSE: 0.10040, Cosine: 0.73041, Spectral Angle: 0.52134
# precursor level - Accuracy: 0.69918, Sensitivity: 1.00000, Specificity: 0.00000
# precursor level - L1: 0.24360, MSE: 0.09915, Cosine: 0.75876, Spectral Angle: 0.55815
# averaged over col - Accuracy: 0.44360, Sensitivity: 0.98723, Specificity: 0.00000
# averaged over col - L1: 0.24018, MSE: 0.10620, Cosine: 0.39432, Spectral Angle: 0.27216
#
# estimator_A - 1
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.65813, Sensitivity: 1.00000, Specificity: 0.00000
# frag ion level - L1: 0.23964, MSE: 0.10044, Cosine: 0.73031, Spectral Angle: 0.52124
# precursor level - Accuracy: 0.69994, Sensitivity: 1.00000, Specificity: 0.00000
# precursor level - L1: 0.24354, MSE: 0.09925, Cosine: 0.75878, Spectral Angle: 0.55821
# averaged over col - Accuracy: 0.44041, Sensitivity: 0.97872, Specificity: 0.00000
# averaged over col - L1: 0.23991, MSE: 0.10624, Cosine: 0.39057, Spectral Angle: 0.26968
#
# estimator_A - 2
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.65778, Sensitivity: 1.00000, Specificity: 0.00000
# frag ion level - L1: 0.24021, MSE: 0.10087, Cosine: 0.72922, Spectral Angle: 0.52024
# precursor level - Accuracy: 0.69966, Sensitivity: 1.00000, Specificity: 0.00000
# precursor level - L1: 0.24393, MSE: 0.09956, Cosine: 0.75807, Spectral Angle: 0.55755
# averaged over col - Accuracy: 0.44379, Sensitivity: 0.98298, Specificity: 0.00000
# averaged over col - L1: 0.24025, MSE: 0.10641, Cosine: 0.39359, Spectral Angle: 0.27169
#
# estimator_A - 3
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.65743, Sensitivity: 1.00000, Specificity: 0.00000
# frag ion level - L1: 0.24007, MSE: 0.10078, Cosine: 0.72912, Spectral Angle: 0.52014
# precursor level - Accuracy: 0.69976, Sensitivity: 1.00000, Specificity: 0.00000
# precursor level - L1: 0.24363, MSE: 0.09935, Cosine: 0.75808, Spectral Angle: 0.55762
# averaged over col - Accuracy: 0.44288, Sensitivity: 0.98723, Specificity: 0.00000
# averaged over col - L1: 0.24025, MSE: 0.10647, Cosine: 0.39052, Spectral Angle: 0.26957
#
# estimator_A - 4
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.65581, Sensitivity: 1.00000, Specificity: 0.00000
# frag ion level - L1: 0.23995, MSE: 0.10088, Cosine: 0.72868, Spectral Angle: 0.51973
# precursor level - Accuracy: 0.69814, Sensitivity: 1.00000, Specificity: 0.00000
# precursor level - L1: 0.24357, MSE: 0.09945, Cosine: 0.75767, Spectral Angle: 0.55728
# averaged over col - Accuracy: 0.44075, Sensitivity: 0.97447, Specificity: 0.00000
# averaged over col - L1: 0.24083, MSE: 0.10725, Cosine: 0.39030, Spectral Angle: 0.26947
#
# estimator_B - 0
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.81381, Sensitivity: 0.37926, Specificity: 0.83353
# frag ion level - L1: 0.17877, MSE: 0.11849, Cosine: 0.67007, Spectral Angle: 0.46747
# precursor level - Accuracy: 0.80247, Sensitivity: 0.44263, Specificity: 0.76833
# precursor level - L1: 0.17874, MSE: 0.11825, Cosine: 0.68421, Spectral Angle: 0.50845
# averaged over col - Accuracy: 0.71104, Sensitivity: 0.15015, Specificity: 0.91563
# averaged over col - L1: 0.10593, MSE: 0.06677, Cosine: 0.23469, Spectral Angle: 0.16193
#
# estimator_B - 1
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.81446, Sensitivity: 0.38070, Specificity: 0.83305
# frag ion level - L1: 0.17840, MSE: 0.11815, Cosine: 0.67122, Spectral Angle: 0.46846
# precursor level - Accuracy: 0.80318, Sensitivity: 0.44425, Specificity: 0.76841
# precursor level - L1: 0.17869, MSE: 0.11822, Cosine: 0.68500, Spectral Angle: 0.50936
# averaged over col - Accuracy: 0.71852, Sensitivity: 0.15383, Specificity: 0.91493
# averaged over col - L1: 0.10507, MSE: 0.06622, Cosine: 0.24757, Spectral Angle: 0.17046
#
# estimator_B - 2
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.81456, Sensitivity: 0.38161, Specificity: 0.83301
# frag ion level - L1: 0.17876, MSE: 0.11849, Cosine: 0.67051, Spectral Angle: 0.46785
# precursor level - Accuracy: 0.80308, Sensitivity: 0.44473, Specificity: 0.76788
# precursor level - L1: 0.17900, MSE: 0.11846, Cosine: 0.68439, Spectral Angle: 0.50899
# averaged over col - Accuracy: 0.72608, Sensitivity: 0.15896, Specificity: 0.91470
# averaged over col - L1: 0.10602, MSE: 0.06697, Cosine: 0.24557, Spectral Angle: 0.16955
#
# estimator_B - 3
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.81456, Sensitivity: 0.37981, Specificity: 0.83406
# frag ion level - L1: 0.17887, MSE: 0.11864, Cosine: 0.66946, Spectral Angle: 0.46695
# precursor level - Accuracy: 0.80335, Sensitivity: 0.44275, Specificity: 0.76908
# precursor level - L1: 0.17888, MSE: 0.11843, Cosine: 0.68356, Spectral Angle: 0.50819
# averaged over col - Accuracy: 0.72610, Sensitivity: 0.15912, Specificity: 0.91525
# averaged over col - L1: 0.10557, MSE: 0.06675, Cosine: 0.25219, Spectral Angle: 0.17502
#
# estimator_B - 4
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.81315, Sensitivity: 0.37906, Specificity: 0.83404
# frag ion level - L1: 0.17895, MSE: 0.11889, Cosine: 0.66831, Spectral Angle: 0.46596
# precursor level - Accuracy: 0.80151, Sensitivity: 0.44334, Specificity: 0.76795
# precursor level - L1: 0.17882, MSE: 0.11850, Cosine: 0.68310, Spectral Angle: 0.50796
# averaged over col - Accuracy: 0.74046, Sensitivity: 0.15482, Specificity: 0.91453
# averaged over col - L1: 0.10648, MSE: 0.06780, Cosine: 0.24488, Spectral Angle: 0.16866
#
# linear_regression - 0
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.73656, Sensitivity: 0.90876, Specificity: 0.37638
# frag ion level - L1: 0.12887, MSE: 0.05582, Cosine: 0.86122, Spectral Angle: 0.66060
# precursor level - Accuracy: 0.76693, Sensitivity: 0.91975, Specificity: 0.37828
# precursor level - L1: 0.12553, MSE: 0.05382, Cosine: 0.87637, Spectral Angle: 0.69551
# averaged over col - Accuracy: 0.45448, Sensitivity: 0.64853, Specificity: 0.40506
# averaged over col - L1: 0.09392, MSE: 0.04206, Cosine: 0.31287, Spectral Angle: 0.22336
#
# linear_regression - 1
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.72749, Sensitivity: 0.90896, Specificity: 0.34453
# frag ion level - L1: 0.12908, MSE: 0.05591, Cosine: 0.86112, Spectral Angle: 0.66047
# precursor level - Accuracy: 0.75734, Sensitivity: 0.91916, Specificity: 0.32835
# precursor level - L1: 0.12575, MSE: 0.05392, Cosine: 0.87636, Spectral Angle: 0.69565
# averaged over col - Accuracy: 0.44793, Sensitivity: 0.65584, Specificity: 0.39737
# averaged over col - L1: 0.09359, MSE: 0.04184, Cosine: 0.30750, Spectral Angle: 0.21978
#
# linear_regression - 2
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.73607, Sensitivity: 0.91248, Specificity: 0.37112
# frag ion level - L1: 0.12975, MSE: 0.05632, Cosine: 0.86011, Spectral Angle: 0.65921
# precursor level - Accuracy: 0.76897, Sensitivity: 0.92251, Specificity: 0.39045
# precursor level - L1: 0.12615, MSE: 0.05420, Cosine: 0.87562, Spectral Angle: 0.69467
# averaged over col - Accuracy: 0.45473, Sensitivity: 0.65385, Specificity: 0.40378
# averaged over col - L1: 0.09460, MSE: 0.04260, Cosine: 0.30854, Spectral Angle: 0.22048
#
# linear_regression - 3
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.73855, Sensitivity: 0.90924, Specificity: 0.38229
# frag ion level - L1: 0.12946, MSE: 0.05632, Cosine: 0.85997, Spectral Angle: 0.65903
# precursor level - Accuracy: 0.77109, Sensitivity: 0.92068, Specificity: 0.40224
# precursor level - L1: 0.12576, MSE: 0.05407, Cosine: 0.87566, Spectral Angle: 0.69485
# averaged over col - Accuracy: 0.44789, Sensitivity: 0.64844, Specificity: 0.40692
# averaged over col - L1: 0.09398, MSE: 0.04244, Cosine: 0.30641, Spectral Angle: 0.21912
#
# linear_regression - 4
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.73405, Sensitivity: 0.91299, Specificity: 0.36976
# frag ion level - L1: 0.12947, MSE: 0.05625, Cosine: 0.85997, Spectral Angle: 0.65904
# precursor level - Accuracy: 0.76638, Sensitivity: 0.92424, Specificity: 0.38622
# precursor level - L1: 0.12595, MSE: 0.05415, Cosine: 0.87573, Spectral Angle: 0.69497
# averaged over col - Accuracy: 0.44455, Sensitivity: 0.64215, Specificity: 0.40625
# averaged over col - L1: 0.09385, MSE: 0.04281, Cosine: 0.31092, Spectral Angle: 0.22213
#
# nn - 0
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.85900, Sensitivity: 0.85512, Specificity: 0.73070
# frag ion level - L1: 0.07379, MSE: 0.02376, Cosine: 0.94346, Spectral Angle: 0.78490
# precursor level - Accuracy: 0.86952, Sensitivity: 0.87892, Specificity: 0.71183
# precursor level - L1: 0.06868, MSE: 0.02130, Cosine: 0.95200, Spectral Angle: 0.81815
# averaged over col - Accuracy: 0.49117, Sensitivity: 0.48613, Specificity: 0.68324
# averaged over col - L1: 0.05644, MSE: 0.01971, Cosine: 0.45894, Spectral Angle: 0.35050
#
# nn - 1
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.86183, Sensitivity: 0.85325, Specificity: 0.73666
# frag ion level - L1: 0.07344, MSE: 0.02368, Cosine: 0.94368, Spectral Angle: 0.78532
# precursor level - Accuracy: 0.87233, Sensitivity: 0.87717, Specificity: 0.71838
# precursor level - L1: 0.06846, MSE: 0.02131, Cosine: 0.95208, Spectral Angle: 0.81842
# averaged over col - Accuracy: 0.49023, Sensitivity: 0.48280, Specificity: 0.68719
# averaged over col - L1: 0.05576, MSE: 0.01935, Cosine: 0.46271, Spectral Angle: 0.35324
#
# nn - 2
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.86034, Sensitivity: 0.85313, Specificity: 0.73380
# frag ion level - L1: 0.07425, MSE: 0.02400, Cosine: 0.94301, Spectral Angle: 0.78403
# precursor level - Accuracy: 0.87092, Sensitivity: 0.87661, Specificity: 0.71440
# precursor level - L1: 0.06901, MSE: 0.02141, Cosine: 0.95182, Spectral Angle: 0.81785
# averaged over col - Accuracy: 0.49172, Sensitivity: 0.48966, Specificity: 0.68338
# averaged over col - L1: 0.05677, MSE: 0.01991, Cosine: 0.46439, Spectral Angle: 0.35429
#
# nn - 3
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.86210, Sensitivity: 0.84868, Specificity: 0.73946
# frag ion level - L1: 0.07397, MSE: 0.02392, Cosine: 0.94298, Spectral Angle: 0.78398
# precursor level - Accuracy: 0.87255, Sensitivity: 0.87227, Specificity: 0.71950
# precursor level - L1: 0.06879, MSE: 0.02135, Cosine: 0.95178, Spectral Angle: 0.81807
# averaged over col - Accuracy: 0.47298, Sensitivity: 0.47639, Specificity: 0.69026
# averaged over col - L1: 0.05639, MSE: 0.02003, Cosine: 0.45362, Spectral Angle: 0.34697
#
# nn - 4
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.85794, Sensitivity: 0.85452, Specificity: 0.73041
# frag ion level - L1: 0.07383, MSE: 0.02387, Cosine: 0.94317, Spectral Angle: 0.78435
# precursor level - Accuracy: 0.86880, Sensitivity: 0.87814, Specificity: 0.71098
# precursor level - L1: 0.06866, MSE: 0.02132, Cosine: 0.95219, Spectral Angle: 0.81861
# averaged over col - Accuracy: 0.48629, Sensitivity: 0.48560, Specificity: 0.68516
# averaged over col - L1: 0.05682, MSE: 0.02044, Cosine: 0.45995, Spectral Angle: 0.35126
#
# vit - 0
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.95167, Sensitivity: 0.76347, Specificity: 0.92561
# frag ion level - L1: 0.05928, MSE: 0.01800, Cosine: 0.95785, Spectral Angle: 0.81450
# precursor level - Accuracy: 0.95360, Sensitivity: 0.79633, Specificity: 0.92257
# precursor level - L1: 0.05630, MSE: 0.01663, Cosine: 0.96404, Spectral Angle: 0.84472
# averaged over col - Accuracy: 0.67231, Sensitivity: 0.38239, Specificity: 0.89224
# averaged over col - L1: 0.04619, MSE: 0.01542, Cosine: 0.51230, Spectral Angle: 0.40378
#
# vit - 1
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.95096, Sensitivity: 0.76488, Specificity: 0.92406
# frag ion level - L1: 0.05871, MSE: 0.01786, Cosine: 0.95806, Spectral Angle: 0.81496
# precursor level - Accuracy: 0.95278, Sensitivity: 0.79719, Specificity: 0.92071
# precursor level - L1: 0.05576, MSE: 0.01647, Cosine: 0.96416, Spectral Angle: 0.84563
# averaged over col - Accuracy: 0.64047, Sensitivity: 0.37837, Specificity: 0.88970
# averaged over col - L1: 0.04527, MSE: 0.01501, Cosine: 0.52198, Spectral Angle: 0.41083
#
# vit - 2
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.95446, Sensitivity: 0.75483, Specificity: 0.93077
# frag ion level - L1: 0.05979, MSE: 0.01838, Cosine: 0.95670, Spectral Angle: 0.81196
# precursor level - Accuracy: 0.95601, Sensitivity: 0.78848, Specificity: 0.92728
# precursor level - L1: 0.05676, MSE: 0.01694, Cosine: 0.96306, Spectral Angle: 0.84296
# averaged over col - Accuracy: 0.64872, Sensitivity: 0.36447, Specificity: 0.89964
# averaged over col - L1: 0.04663, MSE: 0.01589, Cosine: 0.51289, Spectral Angle: 0.40443
#
# vit - 3
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.94997, Sensitivity: 0.76390, Specificity: 0.92280
# frag ion level - L1: 0.05878, MSE: 0.01780, Cosine: 0.95818, Spectral Angle: 0.81523
# precursor level - Accuracy: 0.95201, Sensitivity: 0.79572, Specificity: 0.92060
# precursor level - L1: 0.05565, MSE: 0.01626, Cosine: 0.96460, Spectral Angle: 0.84650
# averaged over col - Accuracy: 0.65352, Sensitivity: 0.38049, Specificity: 0.88749
# averaged over col - L1: 0.04591, MSE: 0.01545, Cosine: 0.52305, Spectral Angle: 0.41129
#
# vit - 4
# matrix shape is 2d, convert it to 3d, shepe is:  (610117, 235, 1)
# frag ion level - Accuracy: 0.94875, Sensitivity: 0.77003, Specificity: 0.92075
# frag ion level - L1: 0.05883, MSE: 0.01772, Cosine: 0.95845, Spectral Angle: 0.81584
# precursor level - Accuracy: 0.95053, Sensitivity: 0.80394, Specificity: 0.91647
# precursor level - L1: 0.05574, MSE: 0.01620, Cosine: 0.96495, Spectral Angle: 0.84689
# averaged over col - Accuracy: 0.63200, Sensitivity: 0.37955, Specificity: 0.88731
# averaged over col - L1: 0.04642, MSE: 0.01593, Cosine: 0.51043, Spectral Angle: 0.40247

# %%
# save the results
df = pd.DataFrame(data, columns=col_list)
df.to_csv(os.path.join(output_dir, "evaluation_results.csv"), index=False)
